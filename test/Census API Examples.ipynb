# %%
import pandasreporter as pr
from IPython.display import display_html
api = pr.CensusApi()

# %%
import re
api.search_datasets(re.compile(r'acs.*2015'))
# Out:
# <table>
# <tr><th>Title</th><th>Description</th></tr><tr><td>ACSSF5Y2015<br />
# 2011-2015 American<br />
# Community Survey<br />
# 5-Year Estimates</td><td>The American Community Survey (ACS) is an ongoing survey<br />
# that provides data every year -- giving communities the<br />
# current information they need to plan investments and<br />
# services. The ACS covers a broad range of topics about<br />
# social, economic, demographic, and housing characteristics<br />
# of the U.S. population.  Summary files include the following<br />
# geographies: nation, all states (including DC and Puerto<br />
# Rico), all metropolitan areas, all congressional districts<br />
# (114th congress), all counties, all places, and all tracts<br />
# and block groups.  Summary files contain the most detailed<br />
# cross-tabulations, many of which are published down to block<br />
# groups. The data are population and housing counts. There<br />
# are over 64,000 variables in this dataset.</td></tr><tr><td>ACSProfile5Y2015<br />
# 2011-2015 American<br />
# Community Survey<br />
# 5-Year Profiles</td><td>The American Community Survey (ACS) is an ongoing survey<br />
# that provides data every year -- giving communities the<br />
# current information they need to plan investments and<br />
# services. The ACS covers a broad range of topics about<br />
# social, economic, demographic, and housing characteristics<br />
# of the U.S. population. The data profiles include the<br />
# following geographies: nation, all states (including DC and<br />
# Puerto Rico), all metropolitan areas, all congressional<br />
# districts, all counties, all places and all tracts. Data<br />
# profiles contain broad social, economic, housing, and<br />
# demographic information. The data are presented as both<br />
# counts and percentages. There are over 2,400 variables in<br />
# this dataset.</td></tr><tr><td>ACSCP5Y2015<br />
# 2011-2015 American<br />
# Community Survey<br />
# Comparison Profile</td><td>The American Community Survey (ACS) is an ongoing survey<br />
# that provides data every year -- giving communities the<br />
# current information they need to plan investments and<br />
# services. The ACS covers a broad range of topics about<br />
# social, economic, demographic, and housing characteristics<br />
# of the U.S. population.  The comparison profiles include the<br />
# following geographies: nation, all states (including DC and<br />
# Puerto Rico), all metropolitan areas, all congressional<br />
# districts, all counties and all places with a population of<br />
# 5,000 or more.  Comparison profiles are similar to data<br />
# profiles but also include comparisons with past-year data.<br />
# The current year data are compared with prior 5-Year data<br />
# and include statistical significance testing.  There are<br />
# over 3,000 variables in this dataset.</td></tr><tr><td>ACSCD1152015<br />
# 2015 American<br />
# Community Survey<br />
# 1-Year Data<br />
# Profile 115th<br />
# Congressional<br />
# District</td><td>The American Community Survey (ACS) is an ongoing survey<br />
# that provides data every year -- giving communities the<br />
# current information they need to plan investments and<br />
# services. The ACS covers a broad range of topics about<br />
# social, economic, demographic, and housing characteristics<br />
# of the U.S. population. The 115th Congressional District<br />
# Data Profiles are available for the nation, all 50 states,<br />
# the District of Columbia, and Puerto Rico (at large). Data<br />
# profiles contain broad social, economic, housing, and<br />
# demographic information. The data are presented as<br />
# population counts for over 1,000 distinct variables.</td></tr><tr><td>ACSSF1Y2015<br />
# 2015 American<br />
# Community Survey<br />
# 1-Year Estimates</td><td>The American Community Survey (ACS) is an ongoing survey<br />
# that provides data every year -- giving communities the<br />
# current information they need to plan investments and<br />
# services. The ACS covers a broad range of topics about<br />
# social, economic, demographic, and housing characteristics<br />
# of the U.S. population.    Summary file, Subject tables,<br />
# Data profiles, and Comparison profiles are available for the<br />
# nation, all 50 states, the District of Columbia, Puerto<br />
# Rico, every congressional district, every metropolitan area,<br />
# and all counties and places with populations of 65,000 or<br />
# more.  Summary file contains the most detailed cross-<br />
# tabulations published for areas 65k and more. The data are<br />
# population counts. There are over 62,000 variables in this<br />
# dataset.</td></tr><tr><td>ACSProfile2015<br />
# 2015 American<br />
# Community Survey<br />
# 1-Year Profiles</td><td>The American Community Survey (ACS) is an ongoing survey<br />
# that provides data every year -- giving communities the<br />
# current information they need to plan investments and<br />
# services. The ACS covers a broad range of topics about<br />
# social, economic, demographic, and housing characteristics<br />
# of the U.S. population.    Summary file, Subject tables,<br />
# Data profiles, and Comparison profiles are available for the<br />
# nation, all 50 states, the District of Columbia, Puerto<br />
# Rico, every congressional district, every metropolitan area,<br />
# and all counties and places with populations of 65,000 or<br />
# more.   Data profiles contain broad social, economic,<br />
# housing, and demographic information. The data are presented<br />
# as population counts and percentages. There are over 2,400<br />
# variables in this dataset.</td></tr><tr><td>ACSCP1Y2015<br />
# 2015 American<br />
# Community Survey<br />
# Comparison Profile</td><td>The American Community Survey (ACS) is an ongoing survey<br />
# that provides data every year -- giving communities the<br />
# current information they need to plan investments and<br />
# services. The ACS covers a broad range of topics about<br />
# social, economic, demographic, and housing characteristics<br />
# of the U.S. population.    Summary file, Subject tables,<br />
# Data profiles, and Comparison profiles are available for the<br />
# nation, all 50 states, the District of Columbia, Puerto<br />
# Rico, every congressional district, every metropolitan area,<br />
# and all counties and places with populations of 65,000 or<br />
# more.   Comparison profiles are similar to data profiles but<br />
# also include comparisons with past-year data.  The current<br />
# year data are compared with each of the last four years of<br />
# data and include statistical significance testing.  There<br />
# are over 9,000 variables in this dataset.</td></tr><tr><td>ACSST1Y2015<br />
# 2015 American<br />
# Community Survey<br />
# Subject Tables</td><td>The American Community Survey (ACS) is an ongoing survey<br />
# that provides data every year -- giving communities the<br />
# current information they need to plan investments and<br />
# services. The ACS covers a broad range of topics about<br />
# social, economic, demographic, and housing characteristics<br />
# of the U.S. population.   Summary file, Subject tables, Data<br />
# profiles, and Comparison profiles are available for the<br />
# nation, all 50 states, the District of Columbia, Puerto<br />
# Rico, every congressional district, every metropolitan area,<br />
# and all counties and places with populations of 65,000 or<br />
# more.   Subject tables provide an overview of the estimates<br />
# available in a particular topic.  The data are presented as<br />
# population counts and percentages.  There are over 66,000<br />
# variables in this dataset.</td></tr><tr><td>ACSST5Y2015<br />
# 2015 American<br />
# Community Survey<br />
# Subject Tables</td><td>The American Community Survey (ACS) is an ongoing survey<br />
# that provides data every year -- giving communities the<br />
# current information they need to plan investments and<br />
# services. The ACS covers a broad range of topics about<br />
# social, economic, demographic, and housing characteristics<br />
# of the U.S. population. The subject tables include the<br /

# %%
ds = api.get_dataset('ACSSF5Y2015')
ds
# Out:
# +Dataset ACSSF5Y2015------------------------------------------------------------------------+
# | title       | 2011-2015 American Community Survey 5-Year Estimates                        |
# +-------------+-----------------------------------------------------------------------------+
# | identitfier | http://api.census.gov/data/id/ACSSF5Y2015                                   |
# | description | The American Community Survey (ACS) is an ongoing survey that provides data |
# |             | every year -- giving communities the current information they need to plan  |
# |             | investments and services. The ACS covers a broad range of topics about      |
# |             | social, economic, demographic, and housing characteristics of the U.S.      |
# |             | population.  Summary files include the following geographies: nation, all   |
# |             | states (including DC and Puerto Rico), all metropolitan areas, all          |
# |             | congressional districts (114th congress), all counties, all places, and all |
# |             | tracts and block groups.  Summary files contain the most detailed cross-    |
# |             | tabulations, many of which are published down to block groups. The data are |
# |             | population and housing counts. There are over 64,000 variables in this      |
# |             | dataset.                                                                    |
# | vintage     | 2015                                                                        |
# | Access Url  | https://api.census.gov/data/2015/acs5                                       |
# | Geographies | https://api.census.gov/data/2015/acs5/geography.html                        |
# | Variables   | https://api.census.gov/data/2015/acs5/variables.html                        |
# | Examples    | https://api.census.gov/data/2015/acs5/examples.html                         |
# +-------------+-----------------------------------------------------------------------------+

# %%
#ds.variables

# %%
ds.search_variables('Total population')
# Out:
# <table>
# <tr><th>Name</th><th>Label</th><th>Concept</th><th>Type</th><th>Required</th></tr><tr><td>B01003_001E</td><td>Total</td><td>B01003.  Total Population</td><td>int</td><td></td></tr><tr><td>B01003_001M</td><td>Margin Of Error For!!Total</td><td>B01003.  Total Population</td><td>int</td><td></td></tr><tr><td>B25008_001E</td><td>Total:</td><td>B25008.  Total Population in Occupied Housing Units by Tenure</td><td>int</td><td></td></tr><tr><td>B25008_001M</td><td>Margin Of Error For!!Total:</td><td>B25008.  Total Population in Occupied Housing Units by Tenure</td><td>int</td><td></td></tr><tr><td>B25008_002E</td><td>Owner occupied</td><td>B25008.  Total Population in Occupied Housing Units by Tenure</td><td>int</td><td></td></tr><tr><td>B25008_002M</td><td>Margin Of Error For!!Owner occupied</td><td>B25008.  Total Population in Occupied Housing Units by Tenure</td><td>int</td><td></td></tr><tr><td>B25008_003E</td><td>Renter occupied</td><td>B25008.  Total Population in Occupied Housing Units by Tenure</td><td>int</td><td></td></tr><tr><td>B25008_003M</td><td>Margin Of Error For!!Renter occupied</td><td>B25008.  Total Population in Occupied Housing Units by Tenure</td><td>int</td><td></td></tr><tr><td>B25026_001E</td><td>Total population in occupied housing units:</td><td>B25026. Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit</td><td>int</td><td></td></tr><tr><td>B25026_001M</td><td>Margin of Error for!!Total population in occupied housing units:</td><td>B25026. Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit</td><td>int</td><td></td></tr><tr><td>B25026_002E</td><td>Total population in occupied housing units:!!Owner occupied:</td><td>B25026. Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit</td><td>int</td><td></td></tr><tr><td>B25026_002M</td><td>Margin of Error for!!Total population in occupied housing units:!!Owner occupied:</td><td>B25026. Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit</td><td>int</td><td></td></tr><tr><td>B25026_003E</td><td>Total population in occupied housing units:!!Owner occupied:!!Moved in 2015 or later</td><td>B25026. Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit</td><td>int</td><td></td></tr><tr><td>B25026_003M</td><td>Margin of Error for!!Total population in occupied housing units:!!Owner occupied:!!Moved in 2015 or later</td><td>B25026. Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit</td><td>int</td><td></td></tr><tr><td>B25026_004E</td><td>Total population in occupied housing units:!!Owner occupied:!!Moved in 2010 to 2014</td><td>B25026. Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit</td><td>int</td><td></td></tr><tr><td>B25026_004M</td><td>Margin of Error for!!Total population in occupied housing units:!!Owner occupied:!!Moved in 2010 to 2014</td><td>B25026. Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit</td><td>int</td><td></td></tr><tr><td>B25026_005E</td><td>Total population in occupied housing units:!!Owner occupied:!!Moved in 2000 to 2009</td><td>B25026. Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit</td><td>int</td><td></td></tr><tr><td>B25026_005M</td><td>Margin of Error for!!Total population in occupied housing units:!!Owner occupied:!!Moved in 2000 to 2009</td><td>B25026. Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit</td><td>int</td><td></td></tr><tr><td>B25026_006E</td><td>Total population in occupied housing units:!!Owner occupied:!!Moved in 1990 to 1999</td><td>B25026. Total Population in Occupied Housing Units by Tenure by Year Householder Moved Into Unit</td><td>int</td><td></td></tr><tr><td>B25026_006M</td><td>Margin of Error for!!Total population in occupied housing units:!!Ow ...

# %%
df = ds.fetch_dataframe( 'GEOID', 'NAME', 'B01003_001E', 'B01003_001M', geo_in='state:06', geo_for='county:*')
df.head()
# Out:
# <div>
# <style>
#     .dataframe thead tr:only-child th {
#         text-align: right;
#     }
#
#     .dataframe thead th {
#         text-align: left;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>GEOID</th>
#       <th>NAME</th>
#       <th>B01003_001E</th>
#       <th>B01003_001M</th>
#       <th>state</th>
#       <th>county</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>05000US06001</td>
#       <td>Alameda County, California</td>
#       <td>1584983</td>
#       <td>0</td>
#       <td>06</td>
#       <td>001</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>05000US06003</td>
#       <td>Alpine County, California</td>
#       <td>1131</td>
#       <td>167</td>
#       <td>06</td>
#       <td>003</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>05000US06005</td>
#       <td>Amador County, California</td>
#       <td>36995</td>
#       <td>0</td>
#       <td>06</td>
#       <td>005</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>05000US06007</td>
#       <td>Butte County, California</td>
#       <td>222564</td>
#       <td>0</td>
#       <td>06</td>
#       <td>007</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>05000US06009</td>
#       <td>Calaveras County, California</td>
#       <td>44767</td>
#       <td>0</td>
#       <td>06</td>
#       <td>009</td>
#     </tr>
#   </tbody>
# </table>
# </div>
